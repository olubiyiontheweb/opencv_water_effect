# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
img = cv2.imread("lion.jpg")
gimg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img[:-1])

# %%
plt.show()

# %%
img.shape
# Out:
# (407, 640, 3)

# %%
imgnew = np.zeros((814,640,3),dtype=np.uint8)

# %%
img
# Out:
# array([[[219, 208, 204],
#         [215, 206, 202],
#         [211, 204, 201],
#         ...,
#         [147, 157, 164],
#         [145, 155, 162],
#         [143, 153, 160]],
#
#        [[218, 207, 203],
#         [215, 206, 202],
#         [211, 204, 201],
#         ...,
#         [149, 159, 166],
#         [151, 159, 166],
#         [147, 157, 164]],
#
#        [[215, 206, 203],
#         [212, 205, 202],
#         [208, 203, 202],
#         ...,
#         [153, 161, 168],
#         [155, 161, 168],
#         [152, 160, 167]],
#
#        ...,
#
#        [[ 29,  65, 111],
#         [  0,  37,  82],
#         [  5,  48,  97],
#         ...,
#         [ 65, 130, 158],
#         [ 46, 111, 139],
#         [113, 180, 207]],
#
#        [[ 41,  77, 123],
#         [  0,  25,  70],
#         [  5,  48,  97],
#         ...,
#         [ 76, 143, 170],
#         [ 42, 109, 136],
#         [ 85, 152, 179]],
#
#        [[ 29,  65, 111],
#         [ 44,  83, 128],
#         [ 68, 111, 160],
# ...

# %%
plt.imshow(imgnew[:-1])

# %%
imgnew[:407][:] = img # img appended to new image numpy array

# %%
plt.imshow(imgnew[:-1])

# %%
imginverted = img[::-1]

# %%
plt.imshow(imginverted)

# %%
imgnew[407:][:] = imginverted

# %%
plt.imshow(imgnew)

# %%
cv2.imwrite("lion_water-col.jpg",imgnew)
# Out:
# True
